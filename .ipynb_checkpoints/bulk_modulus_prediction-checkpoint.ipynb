# %%
# read in data with pandas
import pandas as pd
# use numpy for vector and matrix operations
import numpy as np

# composition is a custom made python file that generates composition-based feature vectors (CBFV)
import composition
# utils is a custom made python file that has some useful functions
import utils

# make nice figures
import matplotlib.pyplot as plt
# machine learnign algorithms
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
# preprocessing for the features
from sklearn.preprocessing import StandardScaler, Normalizer
# feature reduction
from sklearn.decomposition import PCA
# import model selection tools
from sklearn.model_selection import cross_validate, cross_val_score,\
                                    cross_val_predict, learning_curve, \
                                    GridSearchCV, KFold
# grab metrics to evaluate our models
from sklearn.metrics import confusion_matrix, classification_report,\
                            r2_score, mean_squared_error

# %%
df_bulk_modulus = pd.read_csv('bulk_modulus_aflow.csv')
df_bulk_modulus.head()
# Out:
#                           ENTRY  AEL VRH bulk modulus  \
# 0     Al1As1 [d1acbf7cd6bbd917]               67.4056
# 1   Al1B1Be1 [7b87669d29858aed]              140.7780
# 2  Al1Ba1Ge1 [e5990f43d042239c]               44.3828
# 3  Al1Ba1Si1 [0655bb1b738565e8]               49.0752
# 4     Al1Bi1 [786c95a74595dac5]               37.8444
#
#    atomic formation enthalpy space group Pearson symbol               DATA
# 0                  -0.487735  216 - F43m            cF8  [API, Out, JSON ]
# 1                  -2.282620  216 - F43m           cF12  [API, Out, JSON ]
# 2                  -0.471822  187 - P6m2            hP3  [API, Out, JSON ]
# 3                  -0.383687  187 - P6m2            hP3  [API, Out, JSON ]
# 4                   0.059670  216 - F43m            cF8  [API, Out, JSON ]

# %%
df_bulk_modulus.drop('DATA', inplace=True, axis=1)
df_bulk_modulus['ENTRY'] = [formula.split(' ')[0] for formula in df_bulk_modulus['ENTRY']]
df_bulk_modulus.head()
# Out:
#                           ENTRY  AEL VRH bulk modulus  \
# 0     Al1As1 [d1acbf7cd6bbd917]               67.4056
# 1   Al1B1Be1 [7b87669d29858aed]              140.7780
# 2  Al1Ba1Ge1 [e5990f43d042239c]               44.3828
# 3  Al1Ba1Si1 [0655bb1b738565e8]               49.0752
# 4     Al1Bi1 [786c95a74595dac5]               37.8444
#
#    atomic formation enthalpy space group Pearson symbol
# 0                  -0.487735  216 - F43m            cF8
# 1                  -2.282620  216 - F43m           cF12
# 2                  -0.471822  187 - P6m2            hP3
# 3                  -0.383687  187 - P6m2            hP3
# 4                   0.059670  216 - F43m            cF8

# %%
[formula.split(' ')[0] for formula in df_bulk_modulus['ENTRY']]
# Out:
# ['Al1As1\xa0[d1acbf7cd6bbd917]',
#  'Al1B1Be1\xa0[7b87669d29858aed]',
#  'Al1Ba1Ge1\xa0[e5990f43d042239c]',
#  'Al1Ba1Si1\xa0[0655bb1b738565e8]',
#  'Al1Bi1\xa0[786c95a74595dac5]',
#  'Al1Bi1O3\xa0[d43abd3deaeccc51]',
#  'Al1C1Ho3\xa0[3ecce9ff5402ec86]',
#  'Al1C1Y3\xa0[a873c04ce401162f]',
#  'Al1Ca1Si1\xa0[a2be57f97c3c3734]',
#  'Al1Ge1Li1\xa0[a16cd7474b3ebbab]',
#  'Al1Ge1Sr1\xa0[f573f77ca303f0e2]',
#  'Al1Li1Si1\xa0[c854f04be2146c1c]',
#  'Al1P1\xa0[bfe6fc7189a9a3a8]',
#  'Al1Sb1\xa0[8efc0f655f5d4309]',
#  'Al1Si1Sr1\xa0[8023faf5b757d0b6]',
#  'Al1Y1\xa0[53bc333b72a0cbd5]',
#  'Al1Y3\xa0[5baa20a85d1739d4]',
#  'Al1Zr3\xa0[d5adc38fa8b953cf]',
#  'Al2As2\xa0[b2af4cca59eb81b2]',
#  'Al2Ba1Si2\xa0[544c2df3889130ff]',
#  'Al2C2Zr4\xa0[c80850c41a89bd06]',
#  'Al2Ge2Y2\xa0[1854ad7843d7457d]',
#  'Al2Hf2\xa0[71942a90fe720e60]',
#  'Al2Hf4\xa0[dd8fe80eb93c30d7]',
#  'Al2Hg1Te4\xa0[9ac7d0ab226ef604]',
#  'Al2K2O4\xa0[b8b7b327da0f7bb8]',
#  'Al2K2Te4\xa0[fe6e33543b6edd63]',
#  'Al2Li10O8\xa0[3a9e66b3bda80de3]',
#  'Al2Li2\xa0[605efbba4d8ede03]',
#  'Al2Li2Te4\xa0[d1883835918feb41]',
#  'Al2O4Rb2\xa0[73ab442bbc850cc0]',
#  'Al2O6Y2\xa0[901d512ca4ebdee5]',
#  'Al2O8P2\xa0[70e9c5ac99a84ddc]',
#  'Al2P2\xa0[e59f919d67ca2745]',
#  'Al2Se4Tl2\xa0[2d87cbc355583fbb]',
#  'Al2Si2Y2\xa0[b3f3bbfddb69a92b]',
#  'Al2Y2\xa0[562b84d604763031]',
#  'Al2Zr2\xa0[433ef15fc7e9cea2]',
#  'Al2Zr4\xa0[5f1511de835d4c8a]',
#  'Al2Zr4\xa0[f6c899d844130b12]',
#  'Al3Hf1\xa0[c4358a51c19fcdd9]',
#  'Al3Hf4\xa0[adf8044883f8c0a1]',
#  'Al3Ho1\xa0[ad5c5cf4045454df]',
#  'Al3Li1\xa0[b451856d02a043f9]',
#  'Al3Mg3Y3\xa0[b0932d269ad7d933]',
#  'Al3Y1\xa0[b309a907feaea8f9]',
#  'Al3Zr1\xa0[552d0f6689b9f474]',
#  'Al3Zr4\xa0[78d63eb4195e54d7]',
#  'Al4Ba1\xa0[089db02d79e92ef6]',
#  'Al4Ba2\xa0[5cb0505df67e7744]',
#  'Al4Ca12Sb12\xa0[e2385ee95ed57efb]',
#  'Al4Ca2\xa0[bd3c0d8b8d79e6d9]',
#  'Al4Hg2Se8\xa0[2f36d8e6ad9e8324]',
#  'Al4Ho2\xa0[7c85a4cf96c49ebd]',
#  'Al4Ho8\xa0[6b114b9ffe1ba9ba]',
#  'Al4Li4\xa0[8f7dba7946e36954]',
#  'Al4Li4O8\xa0[7f1f3925499b0adb]',
#  'Al4Mg2O8\xa0[2ff88bd13c202825]',
#  'Al4Mg2O8\xa0[d957de87b15d4247]',
#  'Al4O10Si2\xa0[38146938a7b4dba5]',
#  'Al4O12Y4\xa0[4792c39561f6d200]',
#  'Al4O8Pb2\xa0[9ff5a3a14dbd891b]',
#  'Al4Se8Sr2\xa0[02c8bb19af7a55da]',
#  'Al4Sr2\xa0[2889a5ebc0c660e7]',
#  'Al4Y2\xa0[54a813a47d2a272b]',
#  'Al4Y8\xa0[a99a4e29778fe125]',
#  'Al5Ca5Si5\xa0[fadae3ba34adcebe]',
#  'Al6C2Zr10\xa0[4f808281378ad03c]',
#  'Al6C6Ho2\xa0[b7f9a01d5542a9e7]',
#  'Al6C6Y2\xa0[fc20c1baececd8b9]',
#  'Al6C8Hf4\xa0[55cd6688d0177c7e]',
#  'Al6C8Zr4\xa0[24e4050ed5191b98]',
#  'Al6Ca6Si6\xa0[92fd0d9d27e7cc56]',
#  'Al6Hf2\xa0[06d78e7954a45ded]',
#  'Al6Zr2\xa0[4f2db5248958cd2a]',
#  'Al8Ba4Ge8\xa0[e68c32e71fefa9f0]',
#  'Al8Ba4Si8\xa0[d5f8ae327ad270d9]',
#  'Al8C2O8\xa0[e285be3c92c9b42d]',
#  'Al8C8Si2\xa0[e848922840b1944a]',
#  'Al8Hf12\xa0[867e6f10a28bcc96]',
#  'Al8Hf4\xa0[c18d6aeb85f16ed5]',
#  'Al8Ho12\xa0[3e889b2ebbefdb97]',
#  'Al8Mg4\xa0[7ae8cfbe27c1265d]',
#  'Al8O12\xa0[c9b85a6eb23d3036]',
#  'Al8O20Si4\xa0[4614a2f5cd447ca6]',
#  'Al8Sb8\xa0[206f48cebe73b76f]',
#  'Al8Y12\xa0[33853d302c8aeea7]',
#  'Al8Zr10\xa0[d53254a247baa5b7]',
#  'Al8Zr12\xa0[a659f3fa4217743a]',
#  'Al8Zr4\xa0[e271e75bc4d33962]',
#  'Al8Zr4\xa0[e2f80048d263595c]',
#  'Al8Zr4\xa0[57d95c24181ec14e]',
#  'Al8Zr4\xa0[c39bb8d6a0701e63]',
#  'As1\xa0[a997e20f53ed2acb]',
#  'As16Mg24\xa0[0860600e60bf426b]',
#  'As16Mg24\xa0[b70e7bcda8c39667]',
#  'As16Mg4\xa0[f4634f69b19ef301]',
#  'As1B1\xa0[bb4427e452977ce7]',
#  'As1B2P1\xa0[2a3d8ff4b637ab68]',
#  'As1Ba1Li1\xa0[bdef8ab58e76c7a6]',
#  'As1Br3Ca3\xa0[490b50d631861556]',
#  'As1Ca3Cl3\xa0[d4d71d73b26b7913]',
#  'As1Ge1\xa0[b52900970e966f51]',
#  'As1Ho1\xa0[15deecb330c335d7]',
#  'As1Li1Mg1\xa0[4031522cfc844fe8]',
#  'As1Na1\xa0[e12969699a989f2c]',
#  'As1Na3\xa0[e04fbc0416e04033]',
#  'As1Te1\xa0[4b7de1503a36bb4a]',
#  'As1Tl1\xa0[cc780562173bd001]',
#  'As1Y1\xa0[2b8d1079f7096770]',
#  'As1Zr1\xa0[12a3994f64b6856d]',
#  'As2Be2Na2\xa0[f20e761d9e2bd204]',
#  'As2Bi2O8\xa0[54bc53f8d5f39ed9]',
#  'As2Ca1Mg2\xa0[c316958c47445e01]',
#  'As2Ca2Rb2\xa0[35ef9bb6ec3b52f3]',
#  'As2Ca4\xa0[74656f687dd34dd0]',
#  'As2Hg1O6\xa0[f932f4c3f81cf063]',
#  'As2Hg2K2\xa0[075befb960a6d22f]',
#  'As2K2Mg2\xa0[d42040244c5945cd]',
#  'As2Mg2Na2\xa0[9e14958ed53bad27]',
#  'As2Na6\xa0[2e7952639cbaba48]',
#  'As2Pb6Zr10\xa0[4edef03cd560c4da]',
#  'As2Rb6Se32\xa0[f38425f6bc10cbcc]',
#  'As2Sb6Zr10\xa0[8658c446cd864e8b]',
#  'As2Sr4\xa0[17d81543edcdd769]',
#  'As3Na3Sr3\xa0[cf4537f3f53c76be]',
#  'As4Ge2Mg2\xa0[a030e1a3f3efd9f6]',
#  'As4Ge3\xa0[223188a15c60fe2f]',
#  'As4Hf4\xa0[426b550514a4403c]',
#  'As4K12Se12\xa0[17d4f25a9a0997c1]',
#  'As4Mg6\xa0[e6aeabf7626b5275]',
#  'As4Na12Se12\xa0[a905d9de297630fa]',
#  'As4O12Sr2\xa0[167e874aca020acc]',
#  'As4Zr4\xa0[7e1e4fa3243f1866]',
#  'As6Sr6\xa0[4f75cb6f21c6ff12]',
#  'As8Ba4Ge8\xa0[c65eb974665e418b]',
#  'As8Hf12\xa0[a72edbac95240550]',
#  'As8Hf4\xa0[6ab6d29cee6c5e4a]',
#  'As8O12\xa0[8f6257240271b02a]',
#  'As8O12\xa0[95ecf65035751e51]',
#  'As8Si4\xa0[89c22958395182cf]',
#  'As8Zr12\xa0[7ad24d44b882c39c]',
#  'As8Zr4\xa0[c4644f5c0da2a257]',
#  'As8Zr4\xa0[a8f883311b07a7ae]',
#  'B12Hf1\xa0[34e06cdc51fc586a]',
#  'B12Ho1\xa0[907f2cf21e911c3b]',
#  'B12Y1\xa0[dcb115cc81848caa]',
#  'B12Zr1\xa0[b8aa0d8cb9a0b8c1]',
#  'B16C16Mg8\xa0[b3e6c35f229ee23b]',
#  'B18Li2\xa0[44d4b92478b2dfd0]',
#  'B1Be2\xa0[114d179739831b45]',
#  'B1Bi1\xa0[39c84b928e375b7f]',
#  'B1C5\xa0[f759c5600121a9e9]',
#  'B1C7\xa0[95bd1aac30ec7a47]',
#  'B1C7\xa0[0401731cb29df494]',
#  'B1C7\xa0[4d13f06b9fe563ef]',
#  'B1Hf1\xa0[153dd3dd8e6895aa]',
#  'B1P1\xa0[598a7a7328a47d85]',
#  'B1Sb1\xa0[8f50db7084cf70ae]',
#  'B1Zr1\xa0[ed71e73c1d9d1a64]',
#  'B28\xa0[0259d68674b800c3]',
#  'B2C2Li2\xa0[ec2438f50fc672d8]',
#  'B2Ca1\xa0[bf66a2c72bbd4990]',
#  'B2Hf1\xa0[09457595b027e910]',
#  'B2Mg1\xa0[e2edff877e89347a]',
#  'B2P2\xa0[947725bf512a4fa0]',
#  'B2Y1\xa0[7ca6e19f28095b86]',
#  'B2Zr1\xa0[08bf56bf0b207b22]',
#  'B48\xa0[e84cd18d210591c3]',
#  'B4C4Ca2\xa0[31227863394cfc7f]',
#  'B4C4Ca2\xa0[77397d097fcfec92]',
#  'B4C4Y2\xa0[564419ad66d91082]',
#  'B6Ba1\xa0[60403665ed82b47b]',
#  'B6Ca1\xa0[5c5618217287430a]',
#  'B6Ho1\xa0[e0ad2ad23e4aafc4]',
#  'B6K1\xa0[bd33403a60f88c3e]',
#  'B6Sr1\xa0[f4874036e4939ad3]',
#  'B6Y1\xa0[c5976272e8f2fc30]',
#  'B8Be4C8\xa0[6975681558eb6cdc]',
#  'Ba1\xa0[7b2394cca289b7b1]',
#  'Ba10Sb8\xa0[a92b58c15da82969]',
#  'Ba1C2\xa0[9aa20030aa116732]',
#  'Ba1Cl2\xa0[6a9703b2d7b80183]',
#  'Ba1Hg1\xa0[19c353e662a40130]',
#  'Ba1Li1P1\xa0[72b0cd273918804e]',
#  'Ba1Li1Si1\xa0[23e26457c91a4e11]',
#  'Ba1Mg2Si2\xa0[1711607563cbbfd5]',
#  'Ba1Mg4Si3\xa0[5be7414fafc81b31]',
#  'Ba1O1\xa0[ca2b185ba242da1e]',
#  'Ba1O2\xa0[46261cca37eaf3ba]',
#  'Ba1O3Pb1\xa0[279962d5dd496031]',
#  'Ba1O3Pb1\xa0[103754afd63d390f]',
#  'Ba1O3Zr1\xa0[7ad05c2450ba8e4c]',
#  'Ba1Se1\xa0[20c956c82d61d753]',
#  'Ba1Se1\xa0[cf0f068c99c6f727]',
#  'Ba1Te1\xa0[f92c7225e1387152]',
#  'Ba1Te1\xa0[e00b430dded98dba]',
#  'Ba2\xa0[863dc62f92621e76]',
#  'Ba2Be26\xa0[e72d9d4159dcccf8]',
#  'Ba2Bi2O6\xa0[6d34e6bcd9f71398]',
#  'Ba2Bi3\xa0[ec10eb407ac3cb2e]',
#  'Ba2C8O8\xa0[ecf1da14185d6e01]',
#  'Ba2Hg1\xa0[5d5d9f727e2fbf3a]',
#  'Ba2Li2P2\xa0[96c130da39b9c3ab]',
#  'Ba2Li2Sb2\xa0[e8f20dd3d3b5e956]',
#  'Ba2O12Te4\xa0[d0ee5c0aa875ff14]',
#  'Ba2O2\xa0[10aba4c9e4bb81e3]',
#  'Ba2O4Zr1\xa0[cc9a5a5a57fa9414]',
#  'Ba2Si46\xa0[4098d627b609f1c2]',
#  'Ba2Te4\xa0[58d9a7827940d4c4]',
#  'Ba2Te6\xa0[0cf0aed63b5cc3c0]',
#  'Ba2Tl4\xa0[e9c6d477da9d6f7b]',
#  'Ba3Bi3Na3\xa0[450c44720658cd0d]',
#  'Ba3Cl6\xa0[bdc362fd57f037e0]',
#  'Ba3Na3P3\xa0[fa5b64b1b6cf8843]',
#  'Ba3O1Pb1\xa0[8059c15ef297632f]',
#  'Ba4Ca4Ge4\xa0[e394f16f4357075d]',
#  'Ba4Ca4Pb4\xa0[84351a3c976236a8]',
#  'Ba4Ge8P8\xa0[4821b17f7b370cb9]',
#  'Ba4Hg8Tl8\xa0[a2d550bade29107a]',
#  'Ba4Sb2\xa0[fab61846b1f5c182]',
#  'Ba4Si8\xa0[571d2fe1358582e6]',
#  'Ba6C60\xa0[1dd6dacf9f704c70]',
#  'Ba6Ge10\xa0[918c033aad3e4407]',
#  'Ba6Mg23\xa0[e5a9323a46d01884]',
#  'Ba6O10Si2\xa0[3c5c4e212c7f9076]',
#  'Ba6P8\xa0[23c79c4a50ec0484]',
#  'Ba6Pb10\xa0[093eac89f3019431]',
#  'Ba6Si46\xa0[66cb7bd138ea245e]',
#  'Ba8Bi6\xa0[6d4bd5e199f2bded]',
#  'Ba8Ge4\xa0[9bf8a506c5f16d2c]',
#  'Ba8Si4\xa0[f4a14c21af9e4959]',
#  'Ba8Si46\xa0[b7b2d144fc5e6d89]',
#  'Be1O1\xa0[db1f17a6f945c29b]',
#  'Be1O1\xa0[c316b8d2b8b69038]',
#  'Be1Se1\xa0[213c549ca0805a87]',
#  'Be1Se1\xa0[ac6b5aceace8d8aa]',
#  'Be1Te1\xa0[9c841f4bebd25fd6]',
#  'Be1Te1\xa0[71f2b452c887d0bd]',
#  'Be24P16\xa0[473d6cf16feebd74]',
#  'Be26Ca2\xa0[ae212ec034e7c653]',
#  'Be26Hf2\xa0[0bdcb21b070ee9c8]',
#  'Be26Ho2\xa0[e3977bd14545293c]',
#  'Be26Mg2\xa0[a513c57b276194cc]',
#  'Be26Sb2\xa0[bcffe2cd231ff59a]',
#  'Be26Sr2\xa0[d73b0934ea26239d]',
#  'Be26Zr2\xa0[286acac732fe4ad8]',
#  'Be2C1\xa0[378e092c24555651]',
#  'Be2Hf1\xa0[ba24c7d4fdf2198e]',
#  'Be2Hf2\xa0[6fd30ea64b36137a]',
#  'Be2Hf2Si2\xa0[40fc12ea1012ee6e]',
#  'Be2Li2P2\xa0[3d6a13a697be6ee5]',
#  'Be2Li2Sb2\xa0[35246e62d761d918]',
#  'Be2Na2Sb2\xa0[469d710a3c8090f4]',
#  'Be2O2\xa0[ed51b7b3938f117f]',
#  'Be2Si1\xa0[de5897093b42c24b]',
#  'Be2Zr1\xa0[8e9c46d490db8bb3]',
#  'Be4O4\xa0[c8cff231c8082848]',
#  'Be5Hf1\xa0[9935daabda2d9ae8]',
#  'Be6Cl12\xa0[7d8a11e29070e58c]',
#  'Be6P4\xa0[0b01214ece74b40a]',
#  'Bi1\xa0[27bbd51ad4827863]',
#  'Bi1\xa0[4ff91c1735e07aab]',
#  'Bi16O24\xa0[7f08b280bb028857]',
#  'Bi1Ho1\xa0[7239eb435c5ec897]',
#  'Bi1K3\xa0[6480d7dbdcd7b044]',
#  'Bi1Li1\xa0[d80a8198ef249337]',
#  'Bi1Li1Mg1\xa0[5a8e615d2ad336d3]',
#  'Bi1Li3\xa0[a347088e4932106b]',
#  'Bi1Na1\xa0[d3618ed7c3ce4ee7]',
#  'Bi1O2\xa0[bfbbeb6a9f7e7f5a]',
#  'Bi1Rb3\xa0[fb1260e490372a33]',
#  'Bi1Y1\xa0[c526fe4983dfcffa]',
#  'Bi2Ca4\xa0[7e9e20be4dc29b40]',
#  'Bi2K6\xa0[fdd69cc63d2a62b8]',
#  'Bi2O2Se1\xa0[bd39fcd8abd8e251]',
#  'Bi2Rb6\xa0[e9d97f4d81711a66]',
#  'Bi3Sr1\xa0[e5db61fa74861990]',
#  'Bi4\xa0[fadf792d7b321127]',
#  'Bi4K12Se12\xa0[c254a1e890738c41]',
#  'Bi4K12Te12\xa0[1b77bae9c459f82a]',
#  'Bi4Li4Sr4\xa0[74cc6b30d40d1940]',
#  'Bi4Mg2O12\xa0[71f18f0157cf2698]',
#  'Bi4O12Rb12\xa0[7219f844dcd3bc96]',
#  'Bi4O6\xa0[c61260c70de2d745]',
#  'Bi4Rb12Se12\xa0[13aa186ae78de3e3]',
#  'Bi6Sr8\xa0[a6f93590c6fb4a35]',
#  'Bi8O12\xa0[dfaa12a3d112d79d]',
#  'Br10Pb4Rb2\xa0[898a956acbc9af99]',
#  'Br12K4Te2\xa0[90e130206cc7a035]',
#  'Br1K1\xa0[e02e6c6748e87324]',
#  'Br1K1\xa0[9388b0cb77be29c5]',
#  'Br1K3O1\xa0[037bff19ad42b82f]',
#  'Br1Li1\xa0[20b64628cf74cb53]',
#  'Br1Li3O1\xa0[89e3341519d5b3c3]',
#  'Br1Na1\xa0[81af8c617774153e]',
#  'Br1O1Rb3\xa0[d8062a4e068bf5b6]',
#  'Br1Rb1\xa0[9e643376d04eba9f]',
#  'Br1Rb1\xa0[bb569b66afa76188]',
#  'Br1Tl1\xa0[446e47ea5b60293f]',
#  'Br1Tl1\xa0[c6d52ea37eb98db2]',
#  'Br2O8Y6\xa0[6925b566a277f79d]',
#  'Br2Se4Tl10\xa0[3e3c1d40063cad82]',
#  'Br2Tl2\xa0[c01b5c54b0863da2]',
#  'Br32Si8\xa0[d2a45d24273ee835]',
#  'Br4\xa0[8e7ba568a475142c]',
#  'Br4Ca2\xa0[fdbd47d5f13e4755]',
#  'Br4Na4O12\xa0[ec746eef1975aa25]',
#  'Br4Na4O12\xa0[ef261ad7b35866a4]',
#  'Br4Na4O12\xa0[b454313ab1a5628f]',
#  'Br6K2Se1\xa0[8f493eb9dacbdea3]',
#  'Br6K2Te1\xa0[67e6bb73871b7087]',
#  'Br6Rb2Te1\xa0[496fbc63b1ffb8e4]',
#  'Br8Li6Mg1\xa0[ddee48f6f9bf413e]',
#  'Br9Rb3Sb2\xa0[15bf2c0b12f94d87]',
#  'C10Si10\xa0[500ca05581547ef1]',
#  'C12\xa0[bd79f9fa8154aa95]',
#  'C12\xa0[4a8db6076bc9623d]',
#  'C14Si14\xa0[1f21e330dfcd0965]',
#  'C16\xa0[c9d6a8b917d502f0]',
#  'C16\xa0[d8e58d3bd84cf982]',
#  'C16Si16\xa0[bbef4567d359bebd]',
#  'C18Si18\xa0[c9df5d1184d1640f]',
#  'C19Si19\xa0[dcff963bbddaf43f]',
#  'C1Ge1\xa0[279b6e0ce01db4e4]',
#  'C1Ge1\xa0[8fea397ef68c9f59]',
#  'C1Hf1\xa0[29c35aa38b84cf85]',
#  'C1Hf1\xa0[b47a366c761301a7]',
#  'C1Ho3Tl1\xa0[3e164407c8b6a96b]',
#  'C1Li4O4\xa0[c1a0b04a38cc2cb8]',
#  'C1Na4O4\xa0[5fd7303c36d270a3]',
#  'C1Na4O4\xa0[9ff6e80371443b80]',
#  'C1Pb1Y3\xa0[852a2ce545d87e53]',
#  'C1Si1\xa0[2cab0c35952c733f]',
#  'C1Si1\xa0[0e5c7dd4d4402dff]',
#  'C1Tl1\xa0[becbc8b7468a7e42]',
#  'C1Tl1Y3\xa0[ff2e821a5a105eeb]',
#  'C1Y1\xa0[10e56bff43e34aa4]',
#  'C1Y1\xa0[d1d764ad10d0eb67]',
#  'C1Zr1\xa0[b652e182b2677f30]',
#  'C1Zr1\xa0[05e1e26d2863644d]',
#  'C2\xa0[3ab7e139e1c29c9f]',
#  'C20\xa0[933c788c45a7fb66]',
#  'C21Si21\xa0[1cf77fe9d7170820]',
#  'C2Ca2O6\xa0[c703b43d6ea64c82]',
#  'C2Ho1\xa0[1e5413f968afa354]',
#  'C2K8O8\xa0[58922299f89bc347]',
#  'C2Li4O6\xa0[b1fcd31e74f48b03]',
#  'C2O4\xa0[8014ecff6d78dc91]',
#  'C2O4\xa0[162f8798181bf4d9]',
#  'C2Si2\xa0[19570f9ac6a9e4de]',
#  'C2Tl2Zr4\xa0[5a8c11a2c4607835]',
#  'C2Y1\xa0[b6c018d7d6d960a8]',
#  'C4\xa0[b2688e84030188b8]',
#  'C4\xa0[440c4eee274b61b6]',
#  'C4\xa0[2be120d88682ee01]',
#  'C4Mg2\xa0[f5f78826aac5f3d0]',
#  'C4O12Sr4\xa0[35099e599e89dc40]',
#  'C4O8\xa0[67b5e7f9d47704b0]',
#  'C4Si4\xa0[19345a101fc7f670]',
#  'C60K6\xa0[1984611e297ae73e]',
#  'C60Rb6\xa0[4c15d7310c6901e3]',
#  'C60Sr6\xa0[0cbec882fb6cac14]',
#  'C6Si6\xa0[059e25f57cc58053]',
#  'C8\xa0[a59baaad49eb5ab9]',
#  'C8\xa0[b09fb2c5d1e939ca]',
#  'C8\xa0[bdc82cca41c811c6]',
#  'C8\xa0[2818acf274e5c078]',
#  'C8\xa0[c969067f8a3bbde9]',
#  'C8\xa0[c42dc8ec018245e5]',
#  'C8Na4\xa0[8a7bedc037e80ee4]',
#  'C8Na8\xa0[ae0a4eccd0e65124]',
#  'C8Si4\xa0[6d3e8219641e49de]',
#  'C8Si8\xa0[6db975da951495ba]',
#  'Ca1\xa0[da235dae85798482]',
#  'Ca10Sb6\xa0[da7bbf2f9ae5f54f]',
#  'Ca12Hg4\xa0[ba487a3251dc68dc]',
#  'Ca16Hg36\xa0[fe8eeb1e2af8df90]',
#  'Ca1Hg1\xa0[e1226cf0e66c1033]',
#  'Ca1O1\xa0[9bc8de62e0d0e0ea]',
#  'Ca1O2\xa0[5c70e5ad4906e1a9]',
#  'Ca1O3Si1\xa0[cc56846288079507]',
#  'Ca1O3Zr1\xa0[26237603f1b44cd0]',
#  'Ca1Pb1\xa0[92d8c47bba9fe7a3]',
#  'Ca1Se1\xa0[b167bafb684ed8c2]',
#  'Ca1Se1\xa0[7a5d981a5d714afb]',
#  'Ca1Te1\xa0[f51506e74f2ec57e]',
#  'Ca1Tl1\xa0[e35047fade43799d]',
#  'Ca1Tl3\xa0[281507392358bbd6]',
#  'Ca2Cl4\xa0[8dfd0bb804eca9a6]',
#  'Ca2Ge4\xa0[7617c14e76934d97]',
#  'Ca2Hg6\xa0[a74b412faa7fdc81]',
#  'Ca2O2\xa0[183e65e769b16a0a]',
#  'Ca2O6Si2\xa0[cc315d932b359d19]',
#  'Ca2O8Tl4\xa0[93c414995740eb69]',
#  'Ca2Si1\xa0[d42847d039d9c6d9]',
#  'Ca2Si2\xa0[92aeebce897e852d]',
#  'Ca2Si4\xa0[24502608294dc6bc]',
#  'Ca3Cl3P1\xa0[95667da7a1a06f6e]',
#  'Ca3Ge1O1\xa0[717c612f7c2e23cd]',
#  'Ca3Hg1\xa0[d2bed74bc81630a5]',
#  'Ca3O1Pb1\xa0[b1acaa12b27a4ec1]',
#  'Ca3Tl1\xa0[50ba0e96d5272603]',
#  'Ca4Cl8\xa0[5ed02d9a45e81078]',
#  'Ca4Ge4Mg4\xa0[0ea2f481c2cf44d7]',
#  'Ca4Ge8Li4\xa0[d730f802335716fc]',
#  'Ca4Li4Si8\xa0[4105a79a30e78b58]',
#  'Ca4Mg4Si4\xa0[d4a66226ac320e53]',
#  'Ca4Mg8\xa0[bb7396f83a018dbb]',
#  'Ca4Mg8\xa0[29a39cef1d9c1d1e]',
#  'Ca4O12Si4\xa0[3fe9b288117abbf6]',
#  'Ca4O12Si4\xa0[aba814a45970107d]',
#  'Ca4O12Zr4\xa0[4aa30a659beb47a0]',
#  'Ca4O8Pb2\xa0[829aca069b80de01]',
#  'Ca4Pb4Sr4\xa0[b5b4139aae6f9965]',
#  'Ca4Sb2\xa0[ea9944c476b6a616]',
#  'Ca4Si12\xa0[3895c112ae3a70bc]',
#  'Ca5P8\xa0[cff1d3ae6b3f4da2]',
#  'Ca6Hg4\xa0[89fa2dba45153d8c]',
#  'Ca6P6\xa0[a2f519ee71e8f203]',
#  'Ca7Ge1\xa0[4f2cacf7ff9a274e]',
#  'Ca8Cl12O2\xa0[305466170501fcd5]',
#  'Ca8Ge4\xa0[44a95a3b698dde9c]',
#  'Ca8Pb4\xa0[6dac966aaf0e3e8d]',
#  'Ca8Si4\xa0[9785105a70a544e7]',
#  'Cl16Hg12O4\xa0[0380bb5b899328b4]',
#  'Cl16Hg12O4\xa0[60d3c7e3a655a006]',
#  'Cl16Hg12O4\xa0[ee0d6c769a483b53]',
#  'Cl1K1\xa0[28e41ffe3fada8e0]',
#  'Cl1K1\xa0[d5d8c218ad74d303]',
#  'Cl1K1O4\xa0[2db8da6c4b58612b]',
#  'Cl1Li1\xa0[3d5c7e27f5a6cca6]',
#  'Cl1Na1\xa0[d0c93a9396dc599e]',
#  'Cl1Na3O1\xa0[d896b93f18da7085]',
#  'Cl1O4Rb1\xa0[8b5e77c3f863f92b]',
#  'Cl1O4Tl1\xa0[986d832938067b89]',
#  'Cl1Rb1\xa0[136ebce60ff4446b]',
#  'Cl1Rb1\xa0[5f88595ec1d952d0]',
#  'Cl1Tl1\xa0[45bf324a62447cfb]',
#  'Cl1Tl1\xa0[4d76834a1fbcef1f]',
#  'Cl2Hg2\xa0[7854022399e235d4]',
#  'Cl2Mg1\xa0[1966db47ed65d8c6]',
#  'Cl2O2Y2\xa0[b47b7d37bc74f925]',
#  'Cl2Sr1\xa0[bea65ca25419a241]',
#  'Cl4K2Mg1\xa0[88d04db0ca52280a]',
#  'Cl4Mg2\xa0[be2eab8817d5e84f]',
#  'Cl4Na4O12\xa0[a5b293c638b5e670]',
#  'Cl4Na4O12\xa0[8ff7034f6bd9ca4c]',
#  'Cl6Pb1Rb2\xa0[cd74964c563586e0]',
#  'Cl6Rb2Se1\xa0[ab1349bc362a4777]',
#  'Cl6Rb2Te1\xa0[2acdf816a1ae5c33]',
#  'Cl6Rb2Zr1\xa0[ed428a902e5d41de]',
#  'Cl6Te1Tl2\xa0[2a65e95859e6391e]',
#  'Cl8Mg2Na4\xa0[81ee2ef7b606c650]',
#  'Ge1Hg1Li2\xa0[4407929608d945ae]',
#  'Ge1Mg2\xa0[c3369be780358d85]',
#  'Ge1O3Pb1\xa0[4d366e7f1db50794]',
#  'Ge1O8Zr3\xa0[ffc164090dfb5472]',
#  'Ge1P1\xa0[a568f1b0e4ca73fe]',
#  'Ge1Se1\xa0[736d8e730dd9c794]',
#  'Ge1Te1\xa0[31d2c50b7eb85972]',
#  'Ge2\xa0[4d8d11cb2d8457a7]',
#  'Ge2\xa0[253b629a6a736677]',
#  'Ge2Ho2\xa0[9fd68ea503ecff44]',
#  'Ge2Li4O6\xa0[f098f75fcd178563]',
#  'Ge2Mg2O6\xa0[1962ff1173e55191]',
#  'Ge2Mg4\xa0[a22f82b2c1f85244]',
#  'Ge2Mg4O8\xa0[bfa78171be19e02f]',
#  'Ge2Y2\xa0[ebfb7133a161759b]',
#  'Ge3Li3Y3\xa0[f91247b7cb6550a5]',
#  'Ge3O9Sr3\xa0[1bcd81bf7bd067f5]',
#  'Ge4\xa0[b962425ef6071451]',
#  'Ge4Hf2\xa0[6405f75405bd1e6d]',
#  'Ge4Hf6\xa0[3e2391ad165f4246]',
#  'Ge4Ho4Mg2\xa0[d5fbf49b996f3f8e]',
#  'Ge4Mg2Y4\xa0[4ca4848aaafe4dbb]',
#  'Ge4O24Se8\xa0[8c903411c184b735]',
#  'Ge4O8\xa0[e22f5d71c7644345]',
#  'Ge4O8\xa0[b3fee2a933904fcf]',
#  'Ge4Zr4\xa0[de91f60bf7c435c4]',
#  'Ge6Y10\xa0[b55b129750b661fc]',
#  'Ge8\xa0[0c8ccf8069907fe2]',
#  'Ge8\xa0[01a1f3fb30a91645]',
#  'Ge8Y6\xa0[273c909f7818c460]',
#  'Hf10Si6\xa0[c727db055b8c7d56]',
#  'Hf12P8\xa0[7c1e09b806c06601]',
#  'Hf1O2\xa0[fa3bd3969b846c2b]',
#  'Hf1O3Pb1\xa0[639f105c2bbf7f29]',
#  'Hf1O3Sr1\xa0[904000e7545dbe41]',
#  'Hf2\xa0[8a4aa93da3d0b620]',
#  'Hf2Hg1\xa0[f85891c2a99e5be2]',
#  'Hf2O6Sr2\xa0[916c338a6af163c5]',
#  'Hf2O6Sr2\xa0[9384ad572ebdb46b]',
#  'Hf2O8Si2\xa0[88c9119ec9572f57]',
#  'Hf2Si4\xa0[0403be53d36aa9ba]',
#  'Hf3\xa0[816b586b7b4c0b59]',
#  'Hf4Ho4O14\xa0[2abe19acdd8fcd02]',
#  'Hf4O12Sr4\xa0[ab9b8e12b5f5854b]',
#  'Hf4O12Sr4\xa0[3caf75d9979b3ab3]',
#  'Hf4O14Y4\xa0[868f500a39cc59bb]',
#  'Hf4O8\xa0[f199dc9d57adb100]',
#  'Hf4P2Sb2\xa0[a3014ad7fdc77f18]',
#  'Hf4P4\xa0[044ad6823da5aa39]',
#  'Hf6Sb6\xa0[a8e3352f2d4aba9f]',
#  'Hf6Si4\xa0[a9b419dddfacc178]',
#  'Hg1Ho1\xa0[28db322a7eae319f]',
#  'Hg1Li1\xa0[07f268d309e600b2]',
#  'Hg1Mg1\xa0[79a3ecfabd3d15de]',
#  'Hg1O2Rb2\xa0[62d74a601aac5fea]',
#  'Hg1Se1\xa0[58b9ed291d3d9da5]',
#  'Hg1Se1\xa0[d63b3d98960b8a00]',
#  'Hg1Sr1\xa0[147609474cf3a8d3]',
#  'Hg1Te1\xa0[c2384ec3a6ca5619]',
#  'Hg1Te1\xa0[180a54bb2831d9c4]',
#  'Hg1Y1\xa0[1f7c5feab515be03]',
#  'Hg2Ho1\xa0[8e405789ecfe31f7]',
#  'Hg2K2Sb2\xa0[377117f4c7159f05]',
#  'Hg2Mg1\xa0[765c3aff754dfd99]',
#  'Hg2Pb2Sr2\xa0[a9b549be5fa78145]',
#  'Hg2Y1\xa0[72a284b911cfd4a1]',
#  'Hg2Zr6\xa0[afe8109d60c03bd9]',
#  'Hg33K3\xa0[ac7610d35123f5c5]',
#  'Hg33Rb3\xa0[3a84e674e05ac4e6]',
#  'Hg3Zr1\xa0[a68e4529694aa07f]',
#  'Hg4K2\xa0[50b2883feb14cd6e]',
#  'Hg4Mg8\xa0[32c4782e84353cbc]',
#  'Hg4O14Sb4\xa0[bc370dbba9251e37]',
#  'Hg4Sr12\xa0[b194a22dbd1e7b74]',
#  'Hg4Sr6\xa0[b6cf0b50f4b3e8e7]',
#  'Hg6Mg10\xa0[c70e54cbc7c388ab]',
#  'Hg6Y2\xa0[9d32b4eb523876c1]',
#  'Hg6Y2\xa0[df470b37da361912]',
#  'Ho10Sb6\xa0[8f9439cac1e1bff6]',
#  'Ho16O24\xa0[cca0470a5e85e41d]',
#  'Ho16O24\xa0[0dbf333d56d49923]',
#  'Ho1Mg1\xa0[726d2384643098a1]',
#  'Ho1P1\xa0[f19bc59154a5f3fc]',
#  'Ho1Sb1\xa0[b841f96236469afc]',
#  'Ho1Se1\xa0[39e2230d9b5ece5a]',
#  'Ho1Te1\xa0[17798e37f2678015]',
#  'Ho1Tl1\xa0[cdda0a8539ee985a]',
#  'Ho1Tl3\xa0[750354dbab6bfb90]',
#  'Ho2\xa0[cfd5feaf28197208]',
#  'Ho2Si2\xa0[1a66bdfe863db82b]',
#  'Ho2Te4\xa0[d9b7a62ca2362fdc]',
#  'Ho4Mg2Se8\xa0[c4bedc78c6d48e69]',
#  'Ho4Mg8\xa0[55b23f1a73a19a46]',
#  'Ho4Mg8\xa0[8400a768e7283e62]',
#  'Ho4Si4\xa0[68acb772839a33f1]',
#  'Ho6Tl10\xa0[095a60fa8ca0cf2e]',
#  'Ho8Sb6\xa0[99635f09727a0cd0]',
#  'K1\xa0[c45fd3cfd9ab3800]',
#  'K1\xa0[3942a1cdbcb67731]',
#  'K10Te6\xa0[5b8c6ef02fe2db2a]',
#  'K12Sb4Se12\xa0[c385ec02c7fa912e]',
#  'K12Sb4Te12\xa0[d6e8878db8c79997]',
#  'K1Na2Sb1\xa0[5d6d0cc05e18b116]',
#  'K2Li2Se2\xa0[3133a8e5480f33b0]',
#  'K2O1\xa0[9e183a9afc990944]',
#  'K2Se1\xa0[3746bf32a1781888]',
#  'K2Te1\xa0[5a624ba9e35af61b]',
#  'K3Sb1\xa0[75e5a9c0265c43da]',
#  'K4Na4Te4\xa0[8d27db05a832e079]',
#  'K4O12Sb4\xa0[e8c1ce861654b7ed]',
#  'K4O6Pb4\xa0[1a4f8263ad0adfcc]',
#  'K5Pb24\xa0[58f4471901eff079]',
#  'K5Sb4\xa0[129f24d8bdf2c435]',
#  'K6Se6\xa0[232b73a5e7e105bc]',
#  'K8Si46\xa0[bdffe76682314509]',
#  'K8Te12\xa0[cf40cb0bd363aec2]',
#  'Li1Mg1P1\xa0[96211fe3f6ead857]',
#  'Li1Mg4Si2\xa0[4842dd1381fd6937]',
#  'Li1Mg8Si4\xa0[9dd7850f597773b5]',
#  'Li1P1Sr1\xa0[9e558bc257402650]',
#  'Li1Pb1\xa0[a7b9a122dec417bf]',
#  'Li1Tl1\xa0[10844f99e3db9455]',
#  'Li2\xa0[5588568293d3f856]',
#  'Li23Sr6\xa0[9e7d5ff7423c0535]',
#  'Li2Mg1Pb1\xa0[3649f800dc60563b]',
#  'Li2Mg1Si1\xa0[46b836dec2130b87]',
#  'Li2Na1Sb1\xa0[ffd8d4a125d06b15]',
#  'Li2O1\xa0[ebc85927767e092f]',
#  'Li2P2Sr2\xa0[d223febce8427b9d]',
#  'Li2Se1\xa0[01a70da6b0c35513]',
#  'Li2Si4Y4\xa0[ea3c4bf66a460e54]',
#  'Li2Te1\xa0[f237511d90939265]',
#  'Li30Si8\xa0[06dbe0fb8710b322]',
#  'Li3Pb1\xa0[493c1071c3127969]',
#  'Li3Sb1\xa0[03df7938ea1e3872]',
#  'Li3Si3Y3\xa0[c26493e7a28c7532]',
#  'Li40Pb12\xa0[082258cc457161b7]',
#  'Li4Na4Te4\xa0[a9111dde9eb7a8be]',
#  'Li4O10Si4\xa0[dc8cef405f5df2c3]',
#  'Li4O10Si4\xa0[7f9d210e464274d6]',
#  'Li4O12Sb4\xa0[a26bbf21ddeb7256]',
#  'Li4Sb4Sr4\xa0[5af42c7746ab7767]',
#  'Li6P2\xa0[53c0f8e8582ef973]',
#  'Li84Si20\xa0[15cc5b1e464811f1]',
#  'Li8Mg4Si4\xa0[2312999aeb86a11b]',
#  'Li8O8Pb2\xa0[49df2492bd59b040]',
#  'Mg1\xa0[fb28fd89869eb44d]',
#  'Mg1O1\xa0[23344abad821b348]',
#  'Mg1Se1\xa0[be089f53605f184f]',
#  'Mg1Se1\xa0[7625072d0374ea4b]',
#  'Mg1Sr1\xa0[6f4dc5d5578106a5]',
#  'Mg1Te1\xa0[2b705b860e8d18c0]',
#  'Mg1Te1\xa0[634010f2eadb562d]',
#  'Mg1Tl1\xa0[f6fa0908a0c1314a]',
#  'Mg1Y1\xa0[582d36d531b92b8c]',
#  'Mg24P16\xa0[f5bac4598707735a]',
#  'Mg24Sb16\xa0[e48de1a24c1a2400]',
#  'Mg2O12Sb4\xa0[e69027ae6de22ce9]',
#  'Mg2O2\xa0[5af53ce262d3c5cc]',
#  'Mg2O2\xa0[0bd59707063477ec]',
#  'Mg2O6Si2\xa0[e93b29409f63fff3]',
#  'Mg2Pb1\xa0[1099c86fed89ce26]',
#  'Mg2Se2\xa0[6a4f443cf74c4d29]',
#  'Mg2Se8Y4\xa0[3a3a58a5748e494d]',
#  'Mg2Si1\xa0[5b5f6e28c8f6fcae]',
#  'Mg2Te2\xa0[66546a108e411f5b]',
#  'Mg2Te2\xa0[f671deec8391edf1]',
#  'Mg3Tl3Y3\xa0[ef38f4ae340f3eab]',
#  'Mg4O12Se4\xa0[5c15618551d7a263]',
#  'Mg4O12Si4\xa0[fe60676520725e77]',
#  'Mg4O8\xa0[6c69c254c7f8cd4b]',
#  'Mg4O8Si2\xa0[5919341cd70d27f4]',
#  'Mg4O8Si2\xa0[45ac1f4e78abcb1a]',
#  'Mg4Se8\xa0[0646390e435418ab]',
#  'Mg4Si2\xa0[e1275c41d8108b17]',
#  'Mg4Si2\xa0[a607f27fa6c48822]',
#  'Mg4Si4Sr4\xa0[f042ff3e31d7288b]',
#  'Mg4Te8\xa0[4564d244919c96c2]',
#  'Mg6O6\xa0[a23abd0165680631]',
#  'Mg6P4\xa0[e6d01b791d361e77]',
#  'Mg8O8\xa0[6599d22a3b426897]',
#  'Mg8Sr4\xa0[cc3163414e93c3fa]',
#  'Na1\xa0[c3ff1f234732327a]',
#  'Na12Sb4Se12\xa0[30b515df88e0033e]',
#  'Na12Sb4Te12\xa0[d9b6cf00722ac4b8]',
#  'Na2\xa0[cea75a0f94945ef0]',
#  'Na2O1\xa0[74c981a95255f67e]',
#  'Na2O4\xa0[2d7e4e8b51a2f707]',
#  'Na2Se1\xa0[5477ab0c5a3ac253]',
#  'Na2Te1\xa0[90eddf11eef225fb]',
#  'Na3P3Sr3\xa0[5f913b905a1c9b04]',
#  'Na3Sb1Se4\xa0[42a77aaae3125103]',
#  'Na4O12Sb4\xa0[89615efc0a0dfb77]',
#  'Na4O12Sb4\xa0[281cba5a24b471e7]',
#  'Na6O5Pb1\xa0[43ec207d8008a59f]',
#  'Na6P2\xa0[ef00d5055a972435]',
#  'Na6Sb2\xa0[917b743bc2ffbebf]',
#  'Na8Si46\xa0[71d613f278694be9]',
#  'O12Pb4Sr4\xa0[c09a3d9047303b44]',
#  'O12Sb8\xa0[2f95594a0e4b2868]',
#  'O12Sb8\xa0[b4d0bb1d8131888b]',
#  'O12Se4Sr4\xa0[18f40e64a0a7b1c3]',
#  'O12Si6\xa0[5ff559d0c1cac4cd]',
#  'O14Pb4Sb4\xa0[6f7b1c9a0527f360]',
#  'O14Y4Zr4\xa0[574859fb725b71ef]',
#  'O1Pb1Sr3\xa0[b3ad9a78aad79889]',
#  'O1Rb2\xa0[ed5547e7e4115236]',
#  'O1Sr1\xa0[e5529db498f2af80]',
#  'O24Si12\xa0[c349dabcb8dd9e42]',
#  'O24Tl16\xa0[d53b439bbbbad9b9]',
#  'O24Y16\xa0[a4c5261944e5f507]',
#  'O24Y16\xa0[d4d11970ae4cf3d4]',
#  'O28P8Si4\xa0[24975174dd11fbb9]',
#  'O28P8Zr4\xa0[5cb9a9df0e7ab68a]',
#  'O2Pb1\xa0[ae06258781b58bdb]',
#  'O2Pb2\xa0[8e1df3004e6ef769]',
#  'O2Rb1\xa0[b859d5fa2793bbf1]',
#  'O2Rb2\xa0[aab32adb95974548]',
#  'O2Sr1\xa0[3a8b7ba885be1cf7]',
#  'O2Zr1\xa0[50c9df791c600123]',
#  'O2Zr6\xa0[5c347009c594310f]',
#  'O3Pb1Zr1\xa0[d6855b652e1d45f7]',
#  'O3Sr1Zr1\xa0[c4132aed04864439]',
#  'O4\xa0[02f1cbf29c0e74f4]',
#  'O4Si2\xa0[76baad772c7333df]',
#  'O4Si2\xa0[4f902b3d58a95155]',
#  'O4Te2\xa0[33ab67cfa7668558]',
#  'O6Sr2Zr2\xa0[e761ff1ae278f803]',
#  'O6Sr2Zr2\xa0[8c4b81ad5f96cb5c]',
#  'O8P2Y2\xa0[a27222d0173e5065]',
#  'O8Pb2Sr4\xa0[672a0932ff5a3a05]',
#  'O8Si2Zr2\xa0[16bf6a36c052299d]',
#  'O8Si2Zr2\xa0[9a7322a9c8589a25]',
#  'O8Si4\xa0[4cd8887372aa0edb]',
#  'O8Si4\xa0[8f9bf20dda6f77e7]',
#  'O8Si4\xa0[ef608315232ac5d9]',
#  'O8Si4\xa0[e38965ef50bb8383]',
#  'O8Zr4\xa0[ea71a50e2d165d75]',
#  'O8Zr4\xa0[5f3bb43836dab3b3]',
#  'O8Zr4\xa0[70a7a83f10a766bc]',
#  'P1\xa0[57cecbf3dc26e974]',
#  'P1Tl1\xa0[d53b5190863cc376]',
#  'P1Y1\xa0[916e0611d77b56f6]',
#  'P1Zr1\xa0[7068d67e97f2ca12]',
#  'P2Sb2Zr4\xa0[cc641efaedc2dc1f]',
#  'P4\xa0[04b2492d8ca90912]',
#  'P4\xa0[78fd653f68b2e2a8]',
#  'P4Zr4\xa0[cb432b9c96163d15]',
#  'P6Sr6\xa0[58fb9512679028ef]',
#  'P8Si4\xa0[e851bd6b6c7d5b51]',
#  'Pb1Se1\xa0[fc52354a1b50ff61]',
#  'Pb1Se1\xa0[37d22335d6f94c61]',
#  'Pb1Te1\xa0[dcdbde34e53a534d]',
#  'Pb1Te1\xa0[bb46abee42773b80]',
#  'Pb2Te6Tl8\xa0[77324d52cb5156a4]',
#  'Pb4Sr8\xa0[037533a6eb09be9b]',
#  'Pb4Y2\xa0[3a49575b9b567100]',
#  'Rb1\xa0[a16df87dec15ee9c]',
#  'Rb12Sb4Se12\xa0[af26684c8e0291fc]',
#  'Rb2Se1\xa0[bc2372a6d49f86aa]',
#  'Rb2Te1\xa0[e7c5c7c5b4f9a113]',
#  'Rb2Te4Y2\xa0[e7d121efe2e99065]',
#  'Rb4Te2\xa0[1dff4665ff68a2de]',
#  'Rb8Sb8\xa0[8cf08ce1df285278]',
#  'Sb1\xa0[462bb5f411a8e076]',
#  'Sb1Tl1\xa0[035c219449edca3f]',
#  'Sb1Y1\xa0[c4c839a3ba80c695]',
#  'Sb2Sr4\xa0[97c214b186e991bf]',
#  'Sb2Y2Zr2\xa0[f02b07cfc6734325]',
#  'Sb2Zr4\xa0[df488c3596dd282a]',
#  'Sb4Se12Tl12\xa0[a38d3842bc09c46f]',
#  'Sb4Zr4\xa0[de392fe5ed0db5b0]',
#  'Sb6Si2Zr10\xa0[79e7ba831b71aa30]',
#  'Sb6Sr10\xa0[5c6b84f5e53d12c2]',
#  'Sb6Tl21\xa0[f7933008a130dc06]',
#  'Sb6Y8\xa0[9d284b0e2cc08045]',
#  'Sb6Zr6\xa0[19a2db25529e85d4]',
#  'Sb8Zr10\xa0[9fd9c28e5fd4b28c]',
#  'Se12Sr4Zr4\xa0[f8bd7aedd6409450]',
#  'Se1Sr1\xa0[8451928b649b9e7f]',
#  'Se1Tl1\xa0[5ebc0f014499d22b]',
#  'Se1Y1\xa0[6675449ac1e1c290]',
#  'Se4Tl4\xa0[1129ad921009085f]',
#  'Se6\xa0[7d6a2e6c742211e5]',
#  'Si106\xa0[d28694a0827a1a1c]',
#  'Si10Sr10\xa0[dbb92a31d1be602f]',
#  'Si12Sr2\xa0[37dacff32cbe2223]',
#  'Si2\xa0[1e52c555bf94367a]',
#  'Si2\xa0[51dc1417e5b587bc]',
#  'Si2\xa0[760658ac24d836f7]',
#  'Si2Sr4\xa0[b2c68f1ee957adf3]',
#  'Si2Y2\xa0[149e01fa7fe56270]',
#  'Si2Zr2\xa0[27b31a054bfd7432]',
#  'Si2Zr4\xa0[3cbb89aceb65d7eb]',
#  'Si34\xa0[336d342eccc91ed6]',
#  'Si4\xa0[a853db3825c8a64a]',
#  'Si4\xa0[98e7e07c7a209bf7]',
#  'Si4\xa0[20a474bdfc8057ac]',
#  'Si40\xa0[b3f24a1c163b7e13]',
#  'Si41\xa0[474bef052b06e59a]',
#  'Si46\xa0[5c0a166d6f99ed4f]',
#  'Si4Sr2\xa0[a2ccb8c1cb177f1c]',
#  'Si4Sr8\xa0[f3dc42a35f56efd6]',
#  'Si4Y2\xa0[4f01445c6697d0ed]',
#  'Si4Zr2\xa0[0a2aea5c8588c44a]',
#  'Si4Zr4\xa0[777ef5e197aab58b]',
#  'Si6\xa0[c16a53a9044497fa]',
#  'Si6Sr10\xa0[127659e53a1b38d8]',
#  'Si6Zr10\xa0[5c363b4dd6e0208a]',
#  'Si8\xa0[3653e3e40329f003]',
#  'Si8\xa0[f731cf9724e27115]',
#  'Si82\xa0[8e1da8819de201f8]',
#  'Si8Sr4\xa0[821011ffeb0a548e]',
#  'Sr1\xa0[4f01f9799983fd51]',
#  'Sr1Te1\xa0[cb1f9acfa0aecb58]',
#  'Sr1Te1\xa0[866a544848305c9a]',
#  'Sr1Tl1\xa0[fe4e8bc133dd6bd4]',
#  'Sr2\xa0[91f8e6a03809ef58]',
#  'Sr2Tl4\xa0[9b752e7c90f5d4d7]',
#  'Te1Y1\xa0[5b984958dbe89502]',
#  'Te1Zr1\xa0[69a50dc8799998f2]',
#  'Te2\xa0[a8c395dc70d63e16]',
#  'Te2Zr2\xa0[2569fc8b7fa52c87]',
#  'Te2Zr2\xa0[a1f42ab2e5ed413b]',
#  'Te4Y2\xa0[0a9eef79f2c13231]',
#  'Te4Zr4\xa0[98d578e9d4fed7dd]',
#  'Tl1\xa0[b097c396dc7bb87c]',
#  'Tl1Y1\xa0[7a534e0fe4e0e735]',
#  'Tl3Y1\xa0[c08b23695db01790]',
#  'Y2\xa0[5a12ca65b4afe176]',
#  'Zr2\xa0[05869eb713002f0e]']

# %%
df_bulk_modulus['ENTRY'] = [formula.split('\xa0')[0] for formula in df_bulk_modulus['ENTRY']]

# %%
df_bulk_modulus.head()
# Out:
#        ENTRY  AEL VRH bulk modulus  atomic formation enthalpy space group  \
# 0     Al1As1               67.4056                  -0.487735  216 - F43m
# 1   Al1B1Be1              140.7780                  -2.282620  216 - F43m
# 2  Al1Ba1Ge1               44.3828                  -0.471822  187 - P6m2
# 3  Al1Ba1Si1               49.0752                  -0.383687  187 - P6m2
# 4     Al1Bi1               37.8444                   0.059670  216 - F43m
#
#   Pearson symbol
# 0            cF8
# 1           cF12
# 2            hP3
# 3            hP3
# 4            cF8

# %%
df_bulk_modulus.columns = ['formula', 'target', 'enthalpy', 'space_group', 'pearson_symbol']

# %%
df_bulk_modulus.head()
# Out:
#      formula    target  enthalpy space_group pearson_symbol
# 0     Al1As1   67.4056 -0.487735  216 - F43m            cF8
# 1   Al1B1Be1  140.7780 -2.282620  216 - F43m           cF12
# 2  Al1Ba1Ge1   44.3828 -0.471822  187 - P6m2            hP3
# 3  Al1Ba1Si1   49.0752 -0.383687  187 - P6m2            hP3
# 4     Al1Bi1   37.8444  0.059670  216 - F43m            cF8

# %%
df_bulk_modulus['formula'].value_counts()
# Out:
# C8            6
# Al8Zr4        4
# O8Si4         4
# Cl16Hg12O4    3
# Br4Na4O12     3
# C4            3
# Si2           3
# B1C7          3
# Si4           3
# O8Zr4         3
# Cl1Tl1        2
# Ca1Se1        2
# C16           2
# Mg4Si2        2
# O8Si2Zr2      2
# Al2Zr4        2
# Ba1Se1        2
# Hf2O6Sr2      2
# Te2Zr2        2
# Pb1Se1        2
# Li4O10Si4     2
# Ge8           2
# Mg1Te1        2
# Br1K1         2
# C1Na4O4       2
# Si8           2
# Pb1Te1        2
# C12           2
# Be1O1         2
# Br1Rb1        2
#              ..
# Cl2Hg2        1
# Be2C1         1
# O28P8Si4      1
# Be2Na2Sb2     1
# Si4Y2         1
# Se4Tl4        1
# Br6K2Se1      1
# Pb4Y2         1
# Al8Hf12       1
# Hg2Mg1        1
# Al8Zr12       1
# Ba6C60        1
# K4O12Sb4      1
# Si2Zr2        1
# O14Pb4Sb4     1
# B8Be4C8       1
# As2Na6        1
# Li8O8Pb2      1
# Li2Se1        1
# Hg4Sr12       1
# Hg3Zr1        1
# Na6P2         1
# Al8Ba4Si8     1
# Mg1Tl1        1
# Mg1Y1         1
# Hf4O14Y4      1
# P1Tl1         1
# Na2Te1        1
# Ge4Hf2        1
# Br1Li1        1
# Name: formula, Length: 698, dtype: int64

# %%
## take the average of duplicate composition entries
df_bulk_modulus = df_bulk_modulus.groupby('formula').mean().reset_index()
df_bulk_modulus['formula'].value_counts()
# Out:
# O2Pb2          1
# Ba2Te4         1
# Ba2Bi3         1
# Hf4P2Sb2       1
# Si40           1
# Br4Ca2         1
# Sr1Te1         1
# B16C16Mg8      1
# Br12K4Te2      1
# Hf10Si6        1
# Be1Se1         1
# B2P2           1
# Al4Ba2         1
# Al8Ba4Ge8      1
# Mg2O2          1
# Br1O1Rb3       1
# Ge2Li4O6       1
# Mg8Sr4         1
# Al4Ca12Sb12    1
# Sb1            1
# O12Sb8         1
# Ba10Sb8        1
# Sb6Zr6         1
# Ge6Y10         1
# Sb2Sr4         1
# Ge2Mg2O6       1
# Mg2O6Si2       1
# Ho1Te1         1
# Cl1Rb1         1
# Br2O8Y6        1
#               ..
# Al4Mg2O8       1
# Hf4O14Y4       1
# Hf4O12Sr4      1
# P1Tl1          1
# Na2Te1         1
# Ge4Hf2         1
# Na6P2          1
# Al8Zr12        1
# O14Pb4Sb4      1
# Si2Zr2         1
# Ba6C60         1
# As4O12Sr2      1
# Hg4Mg8         1
# Mg4Te8         1
# Na2            1
# C10Si10        1
# Ca4Pb4Sr4      1
# Hg33K3         1
# P4             1
# Na6Sb2         1
# Ba1O3Pb1       1
# Mg3Tl3Y3       1
# C60Sr6         1
# As8Zr4         1
# Ca4Ge4Mg4      1
# O24Y16         1
# Ba3Na3P3       1
# O2Sr1          1
# Hf6Sb6         1
# Br1Li1         1
# Name: formula, Length: 698, dtype: int64
