# %% [markdown]
# # Perform a basic first pass on 'Zhou et al. Band gap data'
#
# ## Import the libraries we will be using

# %%
# read in data with pandas
import pandas as pd
# use numpy for vector and matrix operations
import numpy as np

# composition is a custom made python file that generates composition-based feature vectors (CBFV)
import composition
# utils is a custom made python file that has some useful functions
import utils

# make nice figures
import matplotlib.pyplot as plt
# machine learnign algorithms
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ## Process the data and get it formated for machine learning

# %%
# read in band gap data from Zhou et al. publication:
# J. Phys. Chem. Lett., 2018, 9 (7), pp 1668–1673
#DOI: 10.1021/acs.jpclett.8b00124
#Publication Date (Web): March 13, 2018
df_band_gap = pd.read_excel('jz8b00124_si_002.xlsx')

# %%
df_band_gap.head()
# Out:
#     composition  Eg (eV)
# 0  Hg0.7Cd0.3Te    0.350
# 1          CuBr    3.077
# 2           LuP    1.300
# 3      Cu3SbSe4    0.400
# 4           ZnO    3.436

# %%
# rename columns for use with feature generation
df_band_gap.columns = ['formula', 'target']

# %% [markdown]
# ## Featurize the data

# %%
X, y, formula = composition.generate_features(df_band_gap)
# Out:
# The element: Eu from formula EuYb2Se4 is not currently supported in our database
# The element: Eu from formula Ba3EuP3O12 is not currently supported in our database
# The element: Eu from formula EuSb4S7 is not currently supported in our database
# The element: Eu from formula Na0.75Eu1.625GeSe4 is not currently supported in our database
# The element: Eu from formula EuBiW2O9 is not currently supported in our database
# The element: Eu from formula Sr3EuP3O12 is not currently supported in our database
# The element: Eu from formula Eu3Sb4S9 is not currently supported in our database
# The element: Eu from formula EuHo2Se4 is not currently supported in our database
# The element: Eu from formula Na2EuGeSe4 is not currently supported in our database
# The element: Eu from formula EuLiH3 is not currently supported in our database
# The element: Eu from formula Eu2Se3 is not currently supported in our database
# The element: Eu from formula EuO is not currently supported in our database
# The element: Eu from formula EuBi2Te4 is not currently supported in our database
# The element: Eu from formula EuSe is not currently supported in our database
# The element: Eu from formula EuYb2S4 is not currently supported in our database
# The element: Eu from formula EuBi2Se4 is not currently supported in our database
# The element: Eu from formula Eu3S4 is not currently supported in our database
# The element: Eu from formula Eu2O3 is not currently supported in our database
# The element: Eu from formula Eu7Ga6Sb8 is not currently supported in our database
# The element: Eu from formula EuN is not currently supported in our database
# The element: Eu from formula EuTb2Se4 is not currently supported in our database
# The element: Eu from formula EuTe is not currently supported in our database
# The element: Eu from formula EuIn2Se4 is not currently supported in our database
# The element: Eu from formula EuS is not currently supported in our database
# The element: Eu from formula EuO is not currently supported in our database
# The element: Eu from formula Eu3As2 is not currently supported in our database
# The element: Eu from formula EuIn2Te4 is not currently supported in our database
# The element: Eu from formula EuO is not currently supported in our database
# The element: G from formula GaAs0.1P0.9G1128 is not currently supported in our database
# The element: Eu from formula Eu3Sb4Se9 is not currently supported in our database
# The element: Eu from formula Eu3Se4 is not currently supported in our database
# The element: Eu from formula EuSb2Se4 is not currently supported in our database
# The element: Eu from formula EuGa2S4 is not currently supported in our database
# The element: Eu from formula EuTe is not currently supported in our database
# The element: Eu from formula Eu3In2P4 is not currently supported in our database
# The element: Eu from formula KEuAsS4 is not currently supported in our database
# The element: Eu from formula EuSb4Te7 is not currently supported in our database
# The element: Eu from formula EuS is not currently supported in our database
# The element: Eu from formula Na8Eu2Ge4S12 is not currently supported in our database
# The element: Eu from formula Eu4Te7 is not currently supported in our database
# The element: Eu from formula EuVO4 is not currently supported in our database
# The element: Eu from formula EuLu2Se4 is not currently supported in our database
# The element: Eu from formula EuSb2S4 is not currently supported in our database
# The element: Eu from formula EuVO4 is not currently supported in our database
# The element: Eu from formula EuGa2Te4 is not currently supported in our database
# The element: Eu from formula Eu3Bi4S9 is not currently supported in our database
# The element: Eu from formula Eu1.83Ta15O32 is not currently supported in our database
# The element: Eu from formula EuSnTe2 is not currently supported in our database
# The element: Eu from formula EuSb2BO8 is not currently supported in our database
# The element: Eu from formula EuEr2Se4 is not currently supported in our database
# The element: Eu from formula EuGa2Se4 is not currently supported in our database
# The element: Eu from formula EuS is not currently supported in our database
# The element: Eu from formula EuTe is not currently supported in our database
# The element: Eu from formula EuH2 is not currently supported in our database
# The element: Eu from formula EuDy2Se4 is not currently supported in our database
# The element: Eu from formula Ag0.5Eu1.75GeS4 is not currently supported in our database
# The element: Eu from formula EuIr4In2Ge4 is not currently supported in our database
# The element: Eu from formula EuIn2S4 is not currently supported in our database
# The element: Eu from formula Eu3P2 is not currently supported in our database
# The element: Eu from formula EuAl2O4 is not currently supported in our database
# The element: Eu from formula Eu2SnSe5 is not currently supported in our database
# The element: Eu from formula Eu2Ga2GeS7 is not currently supported in our database
# The element: Eu from formula EuTm2Se4 is not currently supported in our database
# The element: Eu from formula EuCu2SnS4 is not currently supported in our database
# There was an error with the formula: "AgCNO,65", please check the formatting
# There was an error with the formula: "NaZr2TiF11,12", please check the formatting
# There was an error with the formula: "Li3VOF5,1", please check the formatting
# There was an error with the formula: "Li3Mo2P5O18,2", please check the formatting
# There was an error with the formula: "Sr2MgReO6,225", please check the formatting
# There was an error with the formula: "NaLu(Pd3O4)2,200", please check the formatting
# There was an error with the formula: "Ce3Ta(ClO2)3,176", please check the formatting
# There was an error with the formula: "BaAlCu4O7,186", please check the formatting
# There was an error with the formula: "TbBa2IrO6,225", please check the formatting
# The element: Eu from formula EuZn is not currently supported in our database
# There was an error with the formula: "Li4Cu(PO4)2,7", please check the formatting
# There was an error with the formula: "Li5Fe2Ni3O10,2", please check the formatting
# The element: Eu from formula EuCsF3 is not currently supported in our database
# There was an error with the formula: "YCu3(WO3)4,2", please check the formatting
# The element: Eu from formula Eu2Ga9Rh3 is not currently supported in our database
# There was an error with the formula: "Sm2CuAs3O,62", please check the formatting
# The element: Pm from formula PmSnRh2 is not currently supported in our database
# There was an error with the formula: "Ag9Ge2IO8,12", please check the formatting
# There was an error with the formula: "Li2Ni2SbO6,64", please check the formatting
# There was an error with the formula: "Te2MoWS2,164", please check the formatting
# There was an error with the formula: "VCu3(PO4)4,6", please check the formatting
# There was an error with the formula: "RbU2SbS8,8", please check the formatting
# There was an error with the formula: "Sr2ZnReO6,87", please check the formatting
# There was an error with the formula: "Mn3Cr3(TeO8)2,8", please check the formatting
# There was an error with the formula: "Li2MnO2F,63", please check the formatting
# There was an error with the formula: "LiY(CuP)2,164", please check the formatting
# There was an error with the formula: "LiMnP2O7,11", please check the formatting
# There was an error with the formula: "Li4FeNi3O8,2", please check the formatting
# There was an error with the formula: "NdMnSbO,129", please check the formatting
# The element: Eu from formula EuMg2Bi2 is not currently supported in our database
# There was an error with the formula: "KCuPO4,61", please check the formatting
# There was an error with the formula: "Ba3ZrRu2O9,194", please check the formatting
# There was an error with the formula: "Na2Ti2Sb2O,139", please check the formatting
# There was an error with the formula: "Cu3Se2(ClO3)2,12", please check the formatting
# The element: Pm from formula Pm2PtAu is not currently supported in our database
# There was an error with the formula: "NaZrCuTe3,62", please check the formatting
# There was an error with the formula: "CrNiP2O9,62", please check the formatting
# There was an error with the formula: "Na2VCuF7,62", please check the formatting
# There was an error with the formula: "Ba3CaRu2O9,194", please check the formatting
# There was an error with the formula: "FeAg3(CN)6,162", please check the formatting
# There was an error with the formula: "Ce2SiSeO4,57", please check the formatting
# There was an error with the formula: "LiTiSiO4,63", please check the formatting
# The element: Pm from formula Pm2LiGa is not currently supported in our database
# There was an error with the formula: "Ba2LiFe2N3,15", please check the formatting
# There was an error with the formula: "P2H12N7Cl,2", please check the formatting
# There was an error with the formula: "Te3MoWS,156", please check the formatting
# There was an error with the formula: "Nb4Co2PdSe12,12", please check the formatting
# The element: Eu from formula EuPPt is not currently supported in our database
# The element: Pm from formula PmCdPd2 is not currently supported in our database
# There was an error with the formula: "MgCo2(PO5)2,70", please check the formatting
# There was an error with the formula: "Sr2Cu(ClO)2,139", please check the formatting
# There was an error with the formula: "RbNa2NiO2,139", please check the formatting
# There was an error with the formula: "Li5Mn3(FeO5)2,2", please check the formatting
# The element: Eu from formula EuSbO3 is not currently supported in our database
# There was an error with the formula: "Li3Ni(SbO3)4,1", please check the formatting
# There was an error with the formula: "YbBa4(CuO3)3,223", please check the formatting
# There was an error with the formula: "PH2NO2,67", please check the formatting
# There was an error with the formula: "Li6Mn5FeO12,12", please check the formatting
# There was an error with the formula: "CoH2(SN)4,14", please check the formatting
# There was an error with the formula: "Li3Mn3WO8,166", please check the formatting
# There was an error with the formula: "LiFe2(SiO4)2,1", please check the formatting
# There was an error with the formula: "Li5Mn5(SbO6)2,5", please check the formatting
# There was an error with the formula: "Eu2BaMn2O7,63", please check the formatting
# There was an error with the formula: "Mg2GeB2Rh5,127", please check the formatting
# The element: Eu from formula EuCu9Sn4 is not currently supported in our database
# The element: Eu from formula EuPd is not currently supported in our database
# There was an error with the formula: "Ba3NaIrO6,167", please check the formatting
# The element: Pm from formula Pm2LiAl is not currently supported in our database
# There was an error with the formula: "Cr3Ni(PO4)6,146", please check the formatting
# There was an error with the formula: "SrNi2(PO4)2,2", please check the formatting
# There was an error with the formula: "LiLa2IrO6,14", please check the formatting
# There was an error with the formula: "Li3Mn2CuO6,12", please check the formatting
# There was an error with the formula: "Li2Fe3NiO8,160", please check the formatting
# There was an error with the formula: "Mg3Al9FeSi5,189", please check the formatting
# There was an error with the formula: "Li3Cu4NiO8,12", please check the formatting
# There was an error with the formula: "LiMnSiO4,63", please check the formatting
# There was an error with the formula: "Li4Fe3NiO8,166", please check the formatting
# There was an error with the formula: "Ag2P2PbO7,2", please check the formatting
# There was an error with the formula: "Li3Ni2(GeO4)3,230", please check the formatting
# There was an error with the formula: "LiSn(PO3)4,15", please check the formatting
# There was an error with the formula: "LiZn(Fe5O8)2,160", please check the formatting
# There was an error with the formula: "Ba2ReNiO6,225", please check the formatting
# There was an error with the formula: "Na5Fe6(SiO3)12,5", please check the formatting
# There was an error with the formula: "V2Sb(PO4)3,167", please check the formatting
# There was an error with the formula: "Sc2FeB2Ir5,127", please check the formatting
# The element: Eu from formula EuSnO3 is not currently supported in our database
# The element: Eu from formula EuMn2Ge2 is not currently supported in our database
# The element: Eu from formula EuNi12B6 is not currently supported in our database
# There was an error with the formula: "Ba2LaIrO6,12", please check the formatting
# There was an error with the formula: "TiV4CuO12,5", please check the formatting
# There was an error with the formula: "Li2Fe3NiO8,212", please check the formatting
# There was an error with the formula: "Li2Ti3FeO8,160", please check the formatting
# There was an error with the formula: "CuP2(HO3)2,14", please check the formatting
# There was an error with the formula: "BaMn4ZnO8,162", please check the formatting
# There was an error with the formula: "Mn3V2(SiO4)3,230", please check the formatting
# There was an error with the formula: "LaMg(FeO3)2,31", please check the formatting
# The element: Eu from formula EuZn2Ge2 is not currently supported in our database
# There was an error with the formula: "VAg(PSe3)2,5", please check the formatting
# There was an error with the formula: "Y2Fe2Si2C,12", please check the formatting
# There was an error with the formula: "Cs2SeClF6,225", please check the formatting
# There was an error with the formula: "Ba3Nb2CoO9,164", please check the formatting
# There was an error with the formula: "BaLa2CoS5,140", please check the formatting
# There was an error with the formula: "Rb2NaVF6,225", please check the formatting
# There was an error with the formula: "Rb4Si2CuO7,2", please check the formatting
# There was an error with the formula: "Mg4Sc3(SiO3)8,3", please check the formatting
# There was an error with the formula: "Li5Co2O2F5,139", please check the formatting
# There was an error with the formula: "NaFe2(SiO3)4,5", please check the formatting
# The element: Xe from formula Sb2XeF14 is not currently supported in our database
# There was an error with the formula: "LiNiP2O7,15", please check the formatting
# There was an error with the formula: "Li2CrCo3O8,5", please check the formatting
# There was an error with the formula: "Li2Fe3SnO8,4", please check the formatting
# There was an error with the formula: "YbCaInSe4,62", please check the formatting
# There was an error with the formula: "Li8Ti16CuS32,1", please check the formatting
# There was an error with the formula: "Sr2Li2Nb3O10,42", please check the formatting
# There was an error with the formula: "Li2Si4Ni5O14,2", please check the formatting
# The element: Eu from formula Eu2CaO3 is not currently supported in our database
# There was an error with the formula: "Ba6In2NF,225", please check the formatting
# The element: Pm from formula Pm3I is not currently supported in our database
# The element: Pm from formula Pm2IrRh is not currently supported in our database
# There was an error with the formula: "RbCuPdF5,62", please check the formatting
# There was an error with the formula: "EuCuSeO,129", please check the formatting
# There was an error with the formula: "YbH2ClO2,11", please check the formatting
# The element: Pm from formula Pm2LiSi is not currently supported in our database
# The element: Eu from formula Eu2ReO5 is not currently supported in our database
# The element: Pm from formula PmDy3 is not currently supported in our database
# The element: Pm from formula PmCd3 is not currently supported in our database
# There was an error with the formula: "K3LiNb6O15,7", please check the formatting
# There was an error with the formula: "Ba2FeReO6,225", please check the formatting
# There was an error with the formula: "LiV2NiO6,15", please check the formatting
# There was an error with the formula: "SnSb3(PO4)4,6", please check the formatting
# The element: Eu from formula EuTl is not currently supported in our database
# There was an error with the formula: "Li2MnCo3O8,186", please check the formatting
# There was an error with the formula: "Y3Al3NiGe2,189", please check the formatting
# There was an error with the formula: "SrLa3MnO8,63", please check the formatting
# The element: Eu from formula Eu2CuO4 is not currently supported in our database
# There was an error with the formula: "Nb3V(PO4)6,146", please check the formatting
# There was an error with the formula: "Li13Nb14ZnO42,1", please check the formatting
# There was an error with the formula: "Li3V4FeO12,5", please check the formatting
# There was an error with the formula: "Cu2HgGeSe4,121", please check the formatting
# There was an error with the formula: "AlFe4(CuO4)3,204", please check the formatting
# There was an error with the formula: "SmNi2B2C,139", please check the formatting
# There was an error with the formula: "La2Nb2N2O5,1", please check the formatting
# There was an error with the formula: "Ba2ScIrO6,225", please check the formatting
# There was an error with the formula: "Mg2CuWO6,1", please check the formatting
# There was an error with the formula: "Ba2UCuO6,139", please check the formatting
# There was an error with the formula: "Ti2Sb(PO4)3,167", please check the formatting
# There was an error with the formula: "LiCo(CO3)2,148", please check the formatting
# The element: Eu from formula EuNi2As2 is not currently supported in our database
# There was an error with the formula: "Te2Mo2WSe4,156", please check the formatting
# There was an error with the formula: "LiBi2(PO4)3,15", please check the formatting
# There was an error with the formula: "K2B10H9O,14", please check the formatting
# There was an error with the formula: "Ba2FeMoO6,225", please check the formatting
# There was an error with the formula: "LiMnCuO4,74", please check the formatting
# There was an error with the formula: "InFe2CuSe4,121", please check the formatting
# There was an error with the formula: "Li3CrCo3O8,166", please check the formatting
# There was an error with the formula: "Li3Co(NiO2)4,12", please check the formatting
# There was an error with the formula: "Li2Nb2(PO4)3,15", please check the formatting
# There was an error with the formula: "YB2Rh2C,139", please check the formatting
# There was an error with the formula: "Ba3NaIr2O9,194", please check the formatting
# There was an error with the formula: "Ce3MnAlS7,173", please check the formatting
# There was an error with the formula: "Li3Ti3(PO4)4,4", please check the formatting
# There was an error with the formula: "VNi5(PO4)6,146", please check the formatting
# The element: Eu from formula EuFe2Si2 is not currently supported in our database
# There was an error with the formula: "Cs2NaMnF6,166", please check the formatting
# The element: Eu from formula EuAl2Au2 is not currently supported in our database
# There was an error with the formula: "Li2Fe2(PO4)3,15", please check the formatting
# There was an error with the formula: "TiCr3(PO4)6,146", please check the formatting
# There was an error with the formula: "Cs2NaCoF6,166", please check the formatting
# There was an error with the formula: "Li2MnCu3O8,212", please check the formatting
# There was an error with the formula: "Ca3Cu2(ClO2)2,139", please check the formatting
# There was an error with the formula: "LiCuPO4,63", please check the formatting
# There was an error with the formula: "Zr6Al2CoH10,190", please check the formatting
# There was an error with the formula: "Te2Mo(WS2)3,156", please check the formatting
# There was an error with the formula: "ZnCu3P3O13,11", please check the formatting
# The element: Eu from formula EuP2Os2 is not currently supported in our database
# There was an error with the formula: "Cu2H3ClO3,166", please check the formatting
# There was an error with the formula: "NdAl4Ge2Au,166", please check the formatting
# There was an error with the formula: "Li3Ni3(PO4)4,4", please check the formatting
# The element: Eu from formula EuAs2Pd2 is not currently supported in our database
# There was an error with the formula: "Zn3Cu10(TeO6)6,1", please check the formatting
# The element: Pm from formula PmMgCd2 is not currently supported in our database
# The element: Eu from formula EuLi2Sn is not currently supported in our database
# There was an error with the formula: "Sr2GaCo2O7,46", please check the formatting
# There was an error with the formula: "Li4Cr3NiO8,2", please check the formatting
# There was an error with the formula: "Ce4FeSe6O,186", please check the formatting
# There was an error with the formula: "SrLaMn2O6,121", please check the formatting
# There was an error with the formula: "Ce6B2(CBr)3,10", please check the formatting
# The element: Pm from formula PmSbRh2 is not currently supported in our database
# There was an error with the formula: "LuNiBC,129", please check the formatting
# There was an error with the formula: "Li2U(MoO5)2,2", please check the formatting
# There was an error with the formula: "Ba3ErRu2O9,194", please check the formatting
# There was an error with the formula: "Cu4W(SCl)4,139", please check the formatting
# There was an error with the formula: "Sr2CoReO6,14", please check the formatting
# There was an error with the formula: "LiCo7O7F,156", please check the formatting
# There was an error with the formula: "BaDy2CuO5,62", please check the formatting
# There was an error with the formula: "Li5Mn2Cu5O12,5", please check the formatting
# There was an error with the formula: "Fe4Si2Sn7O16,164", please check the formatting
# There was an error with the formula: "Ba2YReO6,225", please check the formatting
# There was an error with the formula: "Fe2Cu(PO4)3,167", please check the formatting
# There was an error with the formula: "Ca2NiIrO6,14", please check the formatting
# There was an error with the formula: "Li2MnCo3O8,5", please check the formatting
# There was an error with the formula: "Li4Cu(PO4)2,1", please check the formatting
# There was an error with the formula: "Tb3Rb2AlF16,194", please check the formatting
# There was an error with the formula: "Rb2NaNiF6,225", please check the formatting
# There was an error with the formula: "NdCu3(RuO3)4,204", please check the formatting
# There was an error with the formula: "Sr3Li4La5O12,6", please check the formatting
# The element: Eu from formula EuSnAu2 is not currently supported in our database
# There was an error with the formula: "LiMgSnPd,216", please check the formatting
# The element: Pm from formula PmMgAu2 is not currently supported in our database
# There was an error with the formula: "Li3Mn2(CoO4)2,1", please check the formatting
# There was an error with the formula: "Li6Fe3Co7O20,10", please check the formatting
# There was an error with the formula: "Ba7Ru4Br2O15,166", please check the formatting
# The element: Eu from formula EuRbO2 is not currently supported in our database
# There was an error with the formula: "Sr2YReO6,225", please check the formatting
# There was an error with the formula: "EuCuSeF,129", please check the formatting
# There was an error with the formula: "YbBa2(CuO2)4,65", please check the formatting
# The element: Eu from formula EuKS2 is not currently supported in our database
# The element: Pm from formula PmHgAu2 is not currently supported in our database
# There was an error with the formula: "Li3Mn(NiO3)2,12", please check the formatting
# There was an error with the formula: "Li2TiMn3O8,166", please check the formatting
# There was an error with the formula: "Li2CrCuO4,74", please check the formatting
# There was an error with the formula: "Li2Ni5(PO4)4,2", please check the formatting
# There was an error with the formula: "LiCo(CO3)2,12", please check the formatting
# There was an error with the formula: "Li3Fe2SbO6,12", please check the formatting
# There was an error with the formula: "Sr2MgIrO6,225", please check the formatting
# There was an error with the formula: "Li3Mn3NiO8,12", please check the formatting
# There was an error with the formula: "Cu9Se4(Cl3O7)2,12", please check the formatting
# There was an error with the formula: "Ba2SmCu3O7,47", please check the formatting
# There was an error with the formula: "Li3Cr3(CuO6)2,14", please check the formatting
# There was an error with the formula: "Li6Fe9CoO20,6", please check the formatting
# There was an error with the formula: "Sr3Co2S2O5,139", please check the formatting
# There was an error with the formula: "Li3V4NiO12,5", please check the formatting
# There was an error with the formula: "Li9Fe3(WO4)7,160", please check the formatting
# The element: Eu from formula EuNaO2 is not currently supported in our database
# The element: Eu from formula EuCo8P5 is not currently supported in our database
# There was an error with the formula: "CsUCuS3,63", please check the formatting
# There was an error with the formula: "Mg2TiIrO6,14", please check the formatting
# There was an error with the formula: "Ba2CaReO6,87", please check the formatting
# There was an error with the formula: "RbUAgS3,63", please check the formatting
# There was an error with the formula: "Li8TiNi7O16,1", please check the formatting
# The element: Eu from formula EuCd11 is not currently supported in our database
# There was an error with the formula: "Li3Fe(CoO2)4,2", please check the formatting
# There was an error with the formula: "Ba2DyCu3O7,47", please check the formatting
# There was an error with the formula: "ThMn4(CuO4)3,204", please check the formatting
# There was an error with the formula: "Li5Co2Ni3O10,10", please check the formatting
# There was an error with the formula: "Na3Mn2(GeO4)3,230", please check the formatting
# The element: Pm from formula YbPmPt2 is not currently supported in our database
# There was an error with the formula: "Mn2Cu(PO4)3,167", please check the formatting
# The element: Eu from formula EuAgSb is not currently supported in our database
# There was an error with the formula: "Te2W2SeS,156", please check the formatting
# There was an error with the formula: "Li6Mn5CoO12,2", please check the formatting
# There was an error with the formula: "Ba14Na8CaN6,176", please check the formatting
# The element: Eu from formula EuCd2Sb2 is not currently supported in our database
# There was an error with the formula: "Li5La3Nb14O42,12", please check the formatting
# There was an error with the formula: "CeCoGeH,129", please check the formatting
# There was an error with the formula: "LiNi2(PO4)3,15", please check the formatting
# The element: Pm from formula PmMgRh2 is not currently supported in our database
# There was an error with the formula: "KTa3CuO9,53", please check the formatting
# The element: Eu from formula EuGe3Pt is not currently supported in our database
# There was an error with the formula: "Li2Co4O7F,8", please check the formatting
# There was an error with the formula: "Li4Mn5NbO12,12", please check the formatting
# There was an error with the formula: "Lu2Fe2Si2C,12", please check the formatting
# There was an error with the formula: "CsVP2S7,5", please check the formatting
# There was an error with the formula: "Rb2SCl6F,225", please check the formatting
# There was an error with the formula: "Sr5Cd2Sb5F,63", please check the formatting
# There was an error with the formula: "Li4Fe7(OF7)2,1", please check the formatting
# There was an error with the formula: "Ce2Cu(NO)2,139", please check the formatting
# There was an error with the formula: "KUCuSe3,63", please check the formatting
# The element: Pm from formula PmLi2Al is not currently supported in our database
# There was an error with the formula: "Li3Cr(NiO2)4,12", please check the formatting
# There was an error with the formula: "Rb2Na2IrO4,14", please check the formatting
# The element: Pm from formula PmLi2Ge is not currently supported in our database
# There was an error with the formula: "Sr3ScNiO6,167", please check the formatting
# The element: Eu from formula EuClO is not currently supported in our database
# The element: Eu from formula Eu2TeO2 is not currently supported in our database
# There was an error with the formula: "LiCu5P3O13,2", please check the formatting
# There was an error with the formula: "Li4Mn5Nb3O16,1", please check the formatting
# There was an error with the formula: "LiMn(PO4)2,14", please check the formatting
# The element: Eu from formula EuScO3 is not currently supported in our database
# There was an error with the formula: "Li4MgNi3O8,166", please check the formatting
# There was an error with the formula: "Ba3YIr2O9,194", please check the formatting
# There was an error with the formula: "DyB2Rh2C,139", please check the formatting
# There was an error with the formula: "MnSb3(PO4)6,146", please check the formatting
# There was an error with the formula: "Li5Fe6(BO3)6,8", please check the formatting
# There was an error with the formula: "Li4Fe2Cu3O10,2", please check the formatting
# There was an error with the formula: "Li6FeNi9O20,2", please check the formatting
# There was an error with the formula: "Li2Ti3FeO8,166", please check the formatting
# There was an error with the formula: "Ce3B2(ClO2)3,176", please check the formatting
# There was an error with the formula: "KLi(WO3)3,9", please check the formatting
# There was an error with the formula: "Li3Co3SbO8,2", please check the formatting
# There was an error with the formula: "Li4V5Cu3O16,8", please check the formatting
# The element: Eu from formula EuZn2Si2 is not currently supported in our database
# There was an error with the formula: "ThFe2SiC,63", please check the formatting
# There was an error with the formula: "Ba3CaIr2O9,164", please check the formatting
# There was an error with the formula: "Li2Ni3TeO8,186", please check the formatting
# There was an error with the formula: "ErAl9(Fe2Si3)2,137", please check the formatting
# There was an error with the formula: "Ti5Zn4(TeO6)3,15", please check the formatting
# The element: Pm from formula Pm2CuGe is not currently supported in our database
# There was an error with the formula: "LiCuPO4,15", please check the formatting
# The element: Pm from formula Pm2LiIr is not currently supported in our database
# There was an error with the formula: "BaZn(MoO2)4,162", please check the formatting
# There was an error with the formula: "LiCu2(CO3)2,1", please check the formatting
# There was an error with the formula: "Li3Ti2(PO4)3,12", please check the formatting
# There was an error with the formula: "Li2FeWO6,146", please check the formatting
# There was an error with the formula: "Li2Fe3CoO8,4", please check the formatting
# There was an error with the formula: "Li4Ni3BiO8,166", please check the formatting
# There was an error with the formula: "Li5Mn6(BO3)6,8", please check the formatting
# There was an error with the formula: "YTi4(CuO4)3,204", please check the formatting
# There was an error with the formula: "Eu2Ge(BO4)2,60", please check the formatting
# There was an error with the formula: "KH(CN2)3,2", please check the formatting
# There was an error with the formula: "Ba2CaOsO6,225", please check the formatting
# There was an error with the formula: "Cu2PHO5,58", please check the formatting
# There was an error with the formula: "Te4MoW3S4,156", please check the formatting
# The element: Eu from formula EuIn2As2 is not currently supported in our database
# There was an error with the formula: "LuU2S3O2,139", please check the formatting
# There was an error with the formula: "Li4NbNi3O8,166", please check the formatting
# There was an error with the formula: "Ca2MnAlO5,46", please check the formatting
# There was an error with the formula: "Li7Ca8Nb12O40,1", please check the formatting
# There was an error with the formula: "Li4Mn5Ni3O16,8", please check the formatting
# There was an error with the formula: "BaTl(MoO3)2,8", please check the formatting
# There was an error with the formula: "Li4Mn(WO4)3,1", please check the formatting
# The element: Eu from formula EuCl3O12 is not currently supported in our database
# There was an error with the formula: "Li3Co4TeO8,12", please check the formatting
# There was an error with the formula: "Li3Mn2(PO4)3,12", please check the formatting
# There was an error with the formula: "RbVP2S7,5", please check the formatting
# There was an error with the formula: "Sr10Al4Si6O,71", please check the formatting
# There was an error with the formula: "Li4Mn5Cu3O16,8", please check the formatting
# The element: Eu from formula EuBi3 is not currently supported in our database
# There was an error with the formula: "Li4Co5SbO12,12", please check the formatting
# There was an error with the formula: "Li3Mn4(PO4)6,2", please check the formatting
# There was an error with the formula: "Cs2SCl6F,225", please check the formatting
# There was an error with the formula: "Ce3NbS3O4,55", please check the formatting
# There was an error with the formula: "EuSeClO3,62", please check the formatting
# The element: Eu from formula EuNiGe3 is not currently supported in our database
# The element: Eu from formula Eu2PBr is not currently supported in our database
# There was an error with the formula: "Li4Ni2(PO4)3,2", please check the formatting
# There was an error with the formula: "LiFe2(PO4)3,1", please check the formatting
# There was an error with the formula: "Li6FeO5F,1", please check the formatting
# There was an error with the formula: "P2H4RhO9,5", please check the formatting
# There was an error with the formula: "Mn3Cr3(CoO8)2,8", please check the formatting
# The element: Pm from formula Pm2NiRh is not currently supported in our database
# There was an error with the formula: "Sr2YBi2O7,46", please check the formatting
# There was an error with the formula: "Li4Co3CuO8,166", please check the formatting
# There was an error with the formula: "Li4Ti5Cr3O16,8", please check the formatting
# There was an error with the formula: "LiMnCoO4,74", please check the formatting
# There was an error with the formula: "Er3Al3NiGe2,189", please check the formatting
# There was an error with the formula: "EuTiClO3,12", please check the formatting
# There was an error with the formula: "Dy7In(CoGe3)4,83", please check the formatting
# There was an error with the formula: "Eu2C(NO)2,164", please check the formatting
# There was an error with the formula: "Tm4In(NiGe2)2,12", please check the formatting
# The element: Eu from formula EuAlO3 is not currently supported in our database
# There was an error with the formula: "Sr2HoRuO6,14", please check the formatting
# The element: Eu from formula EuRhO3 is not currently supported in our database
# There was an error with the formula: "Li3Co2(GeO4)3,230", please check the formatting
# There was an error with the formula: "CuPO4F,2", please check the formatting
# There was an error with the formula: "Eu3BWO9,173", please check the formatting
# There was an error with the formula: "RbB5(H2O3)4,41", please check the formatting
# There was an error with the formula: "Li4Mn3Cr3O12,22", please check the formatting
# There was an error with the formula: "TbBaMn2O6,51", please check the formatting
# There was an error with the formula: "Cu2Hg2SF6,227", please check the formatting
# There was an error with the formula: "Te4Mo(WS)2,187", please check the formatting
# There was an error with the formula: "Li2V3CrO8,166", please check the formatting
# There was an error with the formula: "Ba2BiSbO6,2", please check the formatting
# There was an error with the formula: "Cu4H10SO12,7", please check the formatting
# The element: Pm from formula PmGaAu2 is not currently supported in our database
# There was an error with the formula: "Li4Co2Ni3O10,10", please check the formatting
# There was an error with the formula: "TmU2S3O2,139", please check the formatting
# There was an error with the formula: "CrH9(CN2)3,2", please check the formatting
# There was an error with the formula: "Ca2CuWO6,14", please check the formatting
# There was an error with the formula: "Ba2CoWO6,225", please check the formatting
# There was an error with the formula: "HoSiRu2C,63", please check the formatting
# There was an error with the formula: "Li4TiCr3O8,166", please check the formatting
# There was an error with the formula: "Ba2CuWO6,87", please check the formatting
# There was an error with the formula: "MnFeCoGe,216", please check the formatting
# There was an error with the formula: "LiMn2(PO4)2,29", please check the formatting
# There was an error with the formula: "Li5Cr2Ni5O12,5", please check the formatting
# There was an error with the formula: "Ba4Sm2Cu2O9,118", please check the formatting
# There was an error with the formula: "LiSn(PO3)4,134", please check the formatting
# There was an error with the formula: "Ba14Pd3Ir8O33,5", please check the formatting
# The element: Eu from formula EuSn3 is not currently supported in our database
# The element: Eu from formula EuF3 is not currently supported in our database
# The element: Eu from formula EuTiO3 is not currently supported in our database
# There was an error with the formula: "Cs2NaMgF6,225", please check the formatting
# There was an error with the formula: "Li3FeNi3O8,186", please check the formatting
# There was an error with the formula: "U2Cu2As3O,129", please check the formatting
# The element: Eu from formula Eu3Sn is not currently supported in our database
# There was an error with the formula: "Li3Mn(CuO3)2,12", please check the formatting
# There was an error with the formula: "Li2V3FeO8,8", please check the formatting
# There was an error with the formula: "Li2MnNi3O8,166", please check the formatting
# There was an error with the formula: "In3Bi7(Pb2S9)2,11", please check the formatting
# The element: Eu from formula EuCaO2 is not currently supported in our database
# There was an error with the formula: "Li3Fe(SbO3)4,1", please check the formatting
# There was an error with the formula: "CeZnPO,166", please check the formatting

# %%
bad_formula = "Eu2C(NO)2,164"
print(bad_formula.split(','))
print(bad_formula.split(',')[0])
# Out:
# ['Eu2C(NO)2', '164']
# Eu2C(NO)2

# %%
df_band_gap['formula'] = [formula.split(',')[0] for formula in df_band_gap['formula']]

## There is another issue I notice. There is no element symbol 'G' ....
#The element: G from formula GaAs0.1P0.9G1128 is not currently supported in our database
df_band_gap.replace("GaAs0.1P0.9G1128", "GaAs0.1P0.9", inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
X_train.head()
# Out:
#       sum_C-0    sum_C-1  sum_C-10  sum_C-11   sum_C-12   sum_C-13  \
# 0  101.300000  28.750000  6.600000       0.0  33.100000  33.100000
# 1   24.870370  10.874074  1.666667       0.0  10.818519  10.818519
# 2  140.466667  66.233333 -5.300000       0.0  62.333333  62.333333
# 3  136.250000  32.400000  0.000000       0.0  48.300000  28.650000
# 4   50.850000  29.925000 -0.587500       0.0  29.350000  29.350000
#
#      sum_C-14  sum_C-15  sum_C-16  sum_C-17                ...                 \
# 0   57.850000       0.0       0.0       0.0                ...
# 1   83.925926       0.0       0.0       0.0                ...
# 2  146.366667       0.0       0.0       0.0                ...
# 3   73.550000       0.0       0.0       0.0                ...
# 4   97.775000       0.0       0.0       0.0                ...
#
#    range_voro_coord_subs_atom_mass  range_voro_coord_subs_atom_rad  \
# 0                        67.191000                            5.05
# 1                        99.262000                            4.85
# 2                        41.856600                            5.60
# 3                        10.992223                            6.75
# 4                        88.695000                            7.40
#
#    range_voro_coord_subs_bp  range_voro_coord_subs_elec_aff  \
# 0                     86.00                          6.9020
# 1                   2156.13                          7.8605
# 2                   2410.13                          7.8430
# 3                   2235.00                          7.2950
# 4                   1709.13                          8.7440
#
#    range_voro_coord_subs_first_ion_en  range_voro_coord_subs_hfus  \
# 0                            4.615401                     5.10312
# 1                           11.148346                     5.94601
# 2                            8.457610                     5.87911
# 3                           11.500922                     7.07830
# 4                           12.019347                     7.90421
#
#    range_voro_coord_subs_mol_vol  range_voro_coord_subs_mp  \
# 0                          16.30                     34.98
# 1                          16.87                    605.64
# 2                          14.44                   1416.64
# 3                          14.02                    609.17
# 4                          37.67                    896.40
#
#    range_voro_coord_subs_polzbl  range_voro_coord_subs_therm_cond
# 0                      4.683333                           112.000
# 1                     30.800000                            65.795
# 2                      0.910000                            73.795
# 3                      3.830000                           227.764
# 4                     38.240000                           421.795
#
# [5 rows x 1752 columns]

# %% [markdown]
# ## We can now apply machine learning algorithms to the formated data

# %%
# Initialize a "LinearRegression" object. This will allow us to do a simple linear regression on the data
lr = LinearRegression()
# Call the fit function to perform the ML step
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
print('R2 score =', lr.score(X_test, y_test))
utils.plot_act_vs_pred(y_test, y_pred)

# %%
title = "linear regresion learning curve"
utils.plot_learning_curve(lr, title, X_train, y_train, ylim=(0.1, 1.01), cv=5, n_jobs=-1)

# %%
# Initialize a 'RandomForestRegressor" object.
rf = RandomForestRegressor()
# Call the fit function to perform the ML step
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
print('R2 score =', rf.score(X_test, y_test))
utils.plot_act_vs_pred(y_test, y_pred)
# Out:
# R2 score = 0.7598161170947844

# %%
title = "random forest learning curve"
utils.plot_learning_curve(rf, title, X_train, y_train, ylim=(0.1, 1.01), cv=5, n_jobs=-1)
